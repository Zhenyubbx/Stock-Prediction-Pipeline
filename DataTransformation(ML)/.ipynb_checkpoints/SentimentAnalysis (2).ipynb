# %%
# !pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993243 sha256=78fb368ad014a155bc30ed6cdfc36de2f4890c841b77829ad37d76cd8059151e
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/d9/7e068de779d863bc8f8fc9467d85e25cfe47fa5051fff1a1bb
# Successfully built langdetect
# ...

# %%
import tweepy
from textblob import TextBlob
from langdetect import detect
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.util import *
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from google.colab import files
 
#manually upload json file
uploaded = files.upload()

# will need to change this to retrieve data from BigQuery
# move the tweet cleaning to before loading into BigQuery
# Out:
#      <input type="file" id="files-1a4790ef-225d-40b4-9eab-c60183dc11ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a4790ef-225d-40b4-9eab-c60183dc11ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_json('tsla_tweets.json')

data.head()
# Out:
#         Date                 User  \
# 0 2023-04-17  1491043622598455552
# 1 2023-04-17             21577167
# 2 2023-04-17             50474739
# 3 2023-04-17  1230691768703696896
# 4 2023-04-17  1466444441305059328
#
#                                                Tweet
# 0  @SpeakerMcCarthy @Jim_Jordan @RandPaul @RepMTG...
# 1  RT @BestTrader01: $tsla #tsla = Algo Flow vs S...
# 2  RT @thetrucktown: No more Tesla’s for us. We’l...
# 3  #EURGBP ALL targets hit! 85 pips profit🎯🎯\n\nJ...
# 4  Said it before, Big Tech are more solvent &amp...

# %%
def cleanText(text):

  lang = detect(text) 

  if lang == 'en': 
    text = re.sub(r'@[A-Za-z0-9]+', '', text) #Removes @mentions
    text = re.sub(r'#', '', text) #Removes the # symbol
    text = re.sub(r'RT[\s]+', '', text) #Removes RT
    text = re.sub(r'https?:\/\/\S+','', text) #Removes hyperlinks
    #not cleaning emojis as the vader sentiment analysis takes those into account 
    return text
  else:
    return None #Removes non-english tweets

#Clean text and return
data['Tweet'] = data['Tweet'].astype(str) #Change the tweet data type from object to string
data['Tweet'] = data['Tweet'].apply(cleanText)
data.dropna(subset=['Tweet'], inplace=True) #drop rows with na values in Tweet column
data.reset_index(drop=True, inplace=True) #reset indexes and drop the old index column
data
# Out:
#           Date                 User  \
# 0   2023-04-17  1491043622598455552
# 1   2023-04-17             21577167
# 2   2023-04-17             50474739
# 3   2023-04-17  1230691768703696896
# 4   2023-04-17  1466444441305059328
# ..         ...                  ...
# 156 2023-04-16  1366024409358733312
# 157 2023-04-16  1620114355395125248
# 158 2023-04-16  1638635581755338752
# 159 2023-04-16  1501990523988553728
# 160 2023-04-16  1128037495864745984
#
#                                                  Tweet
# 0     _Jordan    it is layer out right here, plain ...
# 1    : $tsla tsla = Algo Flow vs Stock Price. Calls...
# 2    : No more Tesla’s for us. We’ll stick to selli...
# 3    EURGBP ALL targets hit! 85 pips profit🎯🎯\n\nJo...
# 4    Said it before, Big Tech are more solvent &amp...
# ..                                                 ...
# 156  Get ahead with the weekly market outlook for t...
# 157  : Model X has the amazing scenic views \n\nNo ...
# ...

# %%
# Assigns polarity for each tweet and gives 4 scores: negative, neutral, positive and compound(normalizing the other 3 scores)
# Compound score: between -1(most extreme negative) and +1 (most extreme positive)
# overall positive : (compound score >= 0.05) 
# overall neutral : (compound score > -0.05) and (compound score < 0.05) 
# overall negative : (compound score <= -0.05)
sia = SentimentIntensityAnalyzer()
data['Sentiments'] = data['Tweet'].apply(lambda Tweet: sia.polarity_scores(Tweet))
data = pd.concat([data.drop(['Sentiments'], axis=1), data['Sentiments'].apply(pd.Series)], axis=1)

data
# Out:
#           Date                 User  \
# 0   2023-04-17  1491043622598455552
# 1   2023-04-17             21577167
# 2   2023-04-17             50474739
# 3   2023-04-17  1230691768703696896
# 4   2023-04-17  1466444441305059328
# ..         ...                  ...
# 156 2023-04-16  1366024409358733312
# 157 2023-04-16  1620114355395125248
# 158 2023-04-16  1638635581755338752
# 159 2023-04-16  1501990523988553728
# 160 2023-04-16  1128037495864745984
#
#                                                  Tweet    neg    neu    pos  \
# 0     _Jordan    it is layer out right here, plain ...  0.233  0.767  0.000
# 1    : $tsla tsla = Algo Flow vs Stock Price. Calls...  0.000  1.000  0.000
# 2    : No more Tesla’s for us. We’ll stick to selli...  0.231  0.769  0.000
# 3    EURGBP ALL targets hit! 85 pips profit🎯🎯\n\nJo...  0.000  0.839  0.161
# 4    Said it before, Big Tech are more solvent &amp...  0.000  1.000  0.000
# ...

# %%
# Show percentage of positive, neutral and negative tweets 
positive = 0
neutral = 0
negative = 0
for i in range (0, len(data)):
    get_val = data.compound[i]
    if(float(get_val) <= -0.05):
        negative = negative + 1
    elif(float(get_val) >= 0.05):
        positive = positive + 1
    else:
        neutral = neutral + 1
posperc = (positive/(len(data)))*100
neuperc = (neutral/(len(data)))*100
negperc = (negative/(len(data)))*100
print("% of positive tweets= ", posperc)
print("% of neutral tweets= ", neuperc)
print("% of negative tweets= ", negperc)
arr = np.asarray([posperc, neuperc, negperc], dtype=int)
labels = ['positive','neutral', 'negative']
plt.pie(arr,labels=labels, autopct='%1.1f%%')
plt.title("Breakdown of tweet sentiment analysis")
plt.plot()
# Out:
# % of positive tweets=  50.931677018633536
# % of neutral tweets=  36.024844720496894
# % of negative tweets=  13.043478260869565
# []

# %%
# Daily average sentiment score
totalScore = 0
for i in range (0, len(data)):
  totalScore = totalScore + data.compound[i]
avgScore = totalScore/len(data)

avgScore
# Out:
# 0.19910000000000005
